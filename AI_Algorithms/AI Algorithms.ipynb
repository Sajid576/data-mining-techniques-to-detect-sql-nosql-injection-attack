# %% [markdown]
# Write a Python module that has two methods, one for reading the contents of a file, each line into a dictionary entry. Assume
# that an alphanumeric key is followed by a list of numbers separated by ‘\t’ in a line. The second method should find the sum
# of the elements of the value of a dictionary entry with specified key. You need also to arrange use of the module with entries
# for the name of the file and the key of the dictionary entry.

# %%
dictionary={}

def readFile():
    file = open("/content/drive/MyDrive/My Colab Notebook/final.txt", "r")

    Lines = file.readlines()
    f=0
    for line in Lines:
        if(f==0):
            f+=1
        else:
            x=line.split(',')
            dictionary[x[0] ] = int(x[1]) 

    print(dictionary)


def updateMax():
    MAX_val=-10000
    Max_key=''
    for key,val in dictionary.items():
        if(MAX_val<val):
            MAX_val=val
            Max_key=key
    
    print('Key: '+Max_key)
    print('value: '+str(MAX_val))
    dictionary[Max_key]=MAX_val-10
    print(dictionary)


readFile()
updateMax()
# Out:
# {'A': 50, 'B': 20, 'C': 30, 'D': 80, 'E': 50, 'F': 20}
# Key: D
# value: 80
# {'A': 50, 'B': 20, 'C': 30, 'D': 70, 'E': 50, 'F': 20}

# %% [markdown]
# Write a Python module that has two methods, one for reading the contents of a file, each line into a dictionary entry. Assume
# that a numeric key is followed by a tuple of diverse elements separated by ‘\t’ in a line. The second method should return the
# list of the 1
# st elements of the tuples in the dictionary. You need also to arrange use of the module with an entry for the name of
# the file.

# %%
dictionary={}

def readFile():
    file = open("/content/drive/MyDrive/My Colab Notebook/final2.txt", "r")

    Lines = file.readlines()


    for line in Lines:
        x=line.split('\t')
        key=x[0]
        lst=list(x)
        lst.pop(0)
        myTuple=tuple(lst)
        dictionary[key] = myTuple 

    print(dictionary)

def getFrstElem():
    for key,val in dictionary.items():
        print(key+'-->'+str(val[0]))

readFile()
getFrstElem()
# Out:
# {'a': ('2', '4', '2\n'), 'g': ('12', '23', '22\n'), 'h': ('1', '12', '12', '12\n')}
# a-->2
# g-->12
# h-->1

# %% [markdown]
# Write a Python module that has two methods, one for creating a file with n lines, and another for displaying the average of the
# numeric parts of the first m lines of the file created. Assume that each line of the file contains one sting entry followed by one
# number entry separated by ‘;’. You need also to arrange use of the module with entries for the name of the file and the values
# of m and n.

# %%
import random


def craeteFile(n):
    f = open("/content/drive/MyDrive/My Colab Notebook/final1.txt", "w")
    while(n!=0):
        lineLen=random.randrange(1, 10, 3)
        for i in range(lineLen):
            num=random.randrange(1, 10, 1)
            f.write(str(num))
            if(i!=lineLen-1):
                f.write(';')
        f.write('\n')   
        n-=1
    f.close()
    
def FindAvg(m):
      f = open("/content/drive/MyDrive/My Colab Notebook/final1.txt", "r")
      Lines = f.readlines()
      den=0
      numerator=0
      for line in Lines:
         if(m==0):
            break
         else:
            x=line.split(';')
            lst=list(map(int,x))
            numerator+=sum(lst)
            den+=len(lst)
            m-=1
      AVG=numerator/den
      return AVG





n = int(input('n: '))
craeteFile(n)
m = int(input('m: '))


print('Average of m lines: '+str(FindAvg(m)))
# Out:
# n: 6
# m: 2
# Average of m lines: 4.363636363636363

# %%
# Greedy Best First Search

from queue import PriorityQueue

graph = {
    'i': [ ['a', 35] , ['b', 45] ],

    'a': [['d', 32], ['c', 22]],

    'b': [['d', 28], ['f', 27],['e',36]],

    'd': [['a',32],['b',28],['c', 31], ['g', 30]],

    'c': [['a',22],['d',31],['g', 47]],

    'e': [['b',36],['g',26]],

    'f':[['b',27]]
    
    }

heuristic_values = {'i': 80, 'a': 55, 'b': 42, 'c': 34, 'd': 25, 'e': 20,'f':17, 'g': 0}

pq = PriorityQueue()

pp = []
visited = []
source = 'i'
destination = 'g'

pq.put( ( heuristic_values[source] , source,0) )

while True:
    print("p.pqueue: ")
    print(pq.queue)
    pathAvailable=False
    item = pq.get()    
    pp.append((item[1],item[2] ))   # node,cost
    currentNode=item[1]
    visited.append(currentNode)
    #if destination node is found
    if(currentNode==destination):
        break;

    for neighbour in graph[currentNode]:
        print('neighbour: ')
        print(neighbour)
        if(neighbour[0] not in visited):
            # heuristic value of neighbour,node,cost from current to neighbour --> pq
            pq.put(( heuristic_values[ neighbour[0] ] , neighbour[0], neighbour[1]) ) 
            pathAvailable=True
    
    #if further approach is not possible from a particular node ,then pop last item in the pp
    if(pathAvailable==False):
        pp.pop(-1)        



print("Best possible path using greedy best first search: ")
print(pp)
print('Total cost: ')
total_cost=0;
for item in pp:
    total_cost += item[1]

print(total_cost)
# Out:
# p.pqueue:
# [(80, 'i', 0)]
# neighbour:
# ['a', 35]
# neighbour:
# ['b', 45]
# p.pqueue:
# [(42, 'b', 45), (55, 'a', 35)]
# neighbour:
# ['d', 28]
# neighbour:
# ['f', 27]
# neighbour:
# ['e', 36]
# p.pqueue:
# [(17, 'f', 27), (20, 'e', 36), (25, 'd', 28), (55, 'a', 35)]
# neighbour:
# ['b', 27]
# p.pqueue:
# [(20, 'e', 36), (55, 'a', 35), (25, 'd', 28)]
# neighbour:
# ['b', 36]
# neighbour:
# ['g', 26]
# p.pqueue:
# [(0, 'g', 26), (55, 'a', 35), (25, 'd', 28)]
# Best possible path using greedy best first search:
# [('i', 0), ('b', 45), ('e', 36), ('g', 26)]
# Total cost:
# 107

# %% [markdown]
# ## Refference
# 1) https://www.mygreatlearning.com/blog/a-search-algorithm-in-artificial-intelligence/
#
# 2) https://www.geeksforgeeks.org/a-search-algorithm/

# %%
# A star search algorithm

from queue import PriorityQueue

def aStarAlgo(start_node, stop_node):
         
        open_set = set(start_node) 
        closed_set = set()
        gn = {} #store distance from starting node
        parents = {}# parents contains an adjacency map of all nodes
 
        #ditance of starting node from itself is zero
        g[start_node] = 0
        #start_node is root node i.e it has no parent nodes
        #so start_node is set to its own parent node
        parents[start_node] = start_node
         
         
        while len(open_set) > 0:
            n = None
 
            #node with lowest f() is found
            for v in open_set:
                if n == None or g[v] + heuristic(v) < g[n] + heuristic(n):
                    n = v
             
                     
            if n == stop_node or Graph_nodes[n] == None:
                pass
            else:
                for (m, weight) in get_neighbors(n):
                    #nodes 'm' not in first and last set are added to first
                    #n is set its parent
                    if m not in open_set and m not in closed_set:
                        open_set.add(m)
                        parents[m] = n
                        g[m] = g[n] + weight
                         
     
                    #for each node m,compare its distance from start i.e g(m) to the
                    #from start through n node
                    else:
                        if g[m] > g[n] + weight:
                            #update g(m)
                            g[m] = g[n] + weight
                            #change parent of m to n
                            parents[m] = n
                             
                            #if m in closed set,remove and add to open
                            if m in closed_set:
                                closed_set.remove(m)
                                open_set.add(m)
 
            if n == None:
                print('Path does not exist!')
                return None
 
            # if the current node is the stop_node
            # then we begin reconstructing the path from it to the start_node
            if n == stop_node:
                path = []
 
                while parents[n] != n:
                    path.append(n)
                    n = parents[n]
 
                path.append(start_node)
 
                path.reverse()
 
                print('Path found: {}'.format(path))
                return path
 
 
            # remove n from the open_list, and add it to closed_list
            # because all of his neighbors were inspected
            open_set.remove(n)
            closed_set.add(n)
 
        print('Path does not exist!')
        return None
         



#define fuction to return neighbor and its distance
#from the passed node
def get_neighbors(v):
    if v in Graph_nodes:
        return Graph_nodes[v]
    else:
        return None
        
#for simplicity we ll consider heuristic distances given
#and this function returns heuristic distance for all nodes
def heuristic(n):
        H_dist = {'i': 80, 'a': 55, 'b': 42, 'c': 34, 'd': 25, 'e': 20,'f':17, 'g': 0}
 
        return H_dist[n]
 
#Describe your graph here  
Graph_nodes = {
    'i': [ ['a', 35] , ['b', 45] ],

    'a': [['d', 32], ['c', 22]],

    'b': [['d', 28], ['f', 27],['e',36]],

    'd': [['a',32],['b',28],['c', 31], ['g', 30]],

    'c': [['a',22],['d',31],['g', 47]],

    'e': [['b',36],['g',26]],

    'f':[['b',27]]
    
    }
aStarAlgo('i', 'g')
# Out:
# Path found: ['i', 'a', 'd', 'g']
# ['i', 'a', 'd', 'g']
